# %% [markdown]
# # Parameter identification example
#
# Here is a simple toy model that we use to demonstrate the working of the inference package
#
# $\emptyset \xrightarrow[]{k_1} X \; \; \; \; X \xrightarrow[]{d_1} \emptyset$
#
# ### Run the MCMC algorithm to identify parameters from the experimental data

# %%
# %matplotlib inline
import bioscrape as bs
from bioscrape.types import Model
from bioscrape.simulator import py_simulate_model
from bioscrape.pid_interfaces import *
from bioscrape.emcee_interface import *
import numpy as np
import pylab as plt
import pandas as pd

pid = initialize_mcmc()
# Import bioscrape XML / bioscrape model object M / SBML file
# M  = bs.types.read_model_from_sbml(filename)
pid.M = Model('toy_model.xml')


# Import data from CSV
data_list = []
data = pd.read_csv('test_data.csv', delimiter = '\t', names = ['X', 'time'], skiprows = 1)
data_list.append(list(data.get('X')))
pid.exp_data = np.array(data_list)


pid.prior = {'k1' : ['uniform', 1e-2, 1e3],'d1' : ['gaussian', 0.2, 100, 1e-3]}
pid.params_to_estimate = {'k1':10, 'd1':0.2}
pid.timepoints = np.linspace(0, 100, 50)

pid.type = 'deterministic'


fitted_model, params = pid.run_mcmc(plot_show = True, progress = False)
# Out:
# Sample log-like: 339.527652268316
# Sample log-like: 339.30901233133847
# Sample log-like: 339.48970582458224
# Sample log-like: 339.4904854212391
# Sample log-like: 339.42877061204257
# Sample log-like: 339.51937205621556
# Sample log-like: 339.4437386594412
# Sample log-like: 339.4827139490777
# Sample log-like: 339.5219229155311
# Sample log-like: 339.4135572019619
# Sample log-like: 339.5483005025067
# Sample log-like: 339.5194792453213
# Sample log-like: 339.5298763017788
# Sample log-like: 339.5198088097429
# Sample log-like: 339.56162362791036
# Sample log-like: 339.54119596809096
# Sample log-like: 339.5066590556011
# Sample log-like: 339.4468529859407
# Sample log-like: 339.5701405602433
# Sample log-like: 339.587778698369
# Sample log-like: 339.5111755681859
# Sample log-like: 339.5454745489826
# Sample log-like: 339.54090606686003
# Sample log-like: 339.53232154766295
# Sample log-like: 339.5201284556572
# Sample log-like: 339.47071443659536
# Sample log-like: 339.49714044231456
# Sample log-like: 339.5134930039238
# Sample log-like: 339.49742027923435
# Sample log-like: 339.54966944211617
# Sample log-like: 339.5118148718686
# Sample log-like: 339.40010810885224
# Sample log-like: 339.5339249381525
# Sample log-like: 339.48230151575814
# Sample log-like: 339.49349414317703
# Sample log-like: 339.5414634837367
# Sample log-like: 339.54905054147
# Sample log-like: 339.57190081034076
# Sample log-like: 339.42070246949703
# Sample log-like: 339.5253582173908
# Sample log-like: 339.4514502931396
# Sample log-like: 339.56031044037627
# Sample log-like: 339.50160012762063
# Sample log-like: 339.47067418483243
# Sample log-like: 339.3905322779327
# Sample log-like: 339.5079614114565
# Sample log-like: 339.52031454991834
# Sample log-like: 339.4776131568151
# Sample log-like: 339.5538523591713
# Sample log-like: 339.505860321525
# Sample log-like: 339.4746910913416
# Sample log-like: 339.52274795341765
# Sample log-like: 339.52309252170335
# Sample log-like: 339.528126273007
# Sample log-like: 339.53809394678643
# Sample log-like: 339.5222867995707
# Sample log-like: 339.56453523407697
# Sample log-like: 339.4711615444212
# Sample log-like: 339.53314172640694
# Sample log-like: 339.55450004789975
# Sample log-like: 339.54527229102194
# Sample log-like: 339.4837132454673
# Sample log-like: 339.45710419828254
# Sample log-like: 339.5303021519585
# Sample log-like: 339.51720533960446
# Sample log-like: 339.49197658201314
# Sample log-like: 339.5173467153042
# Sample log-like: 339.4915996560845
# Sample log-like: 339.5870275599675
# Sample log-like: 339.60257459063894
# Sample log-like: 339.53358414429505
# Sample log-like: 339.5475720017934
# Sample log-like: 339.4377343276551
# Sample log-like: 339.4307938395894
# Sample log-like: 339.51930265626675
# Sample log-like: 339.42375772091054
# Sample log-like: 339.46004796231097
# Sample log-like: 339.4688795098523
# Sample log-like: 339.44947383659706
# Sample log-like: 339.5019127154523
# Sample log-like: 339.4052566128226
# Sample log-like: 339.52317922919354
# Sample log-like: 339.4683081767469
# Sample log-like: 339.39068896771767
# Sample log-like: 339.52379398404395
# Sample log-like: 339.5351427549899
# Sample log-like: 339.5449114208833
# Sample log-like: 339.51799608635764
# Sample log-like: 339.5131654891093
# Sample log-like: 339.5240763875029
# Sample log-like: 339.5511712200236
# Sample log-like: 339.5797872376339
# Sample log-like: 339.572383737017
# Sample log-like: 339.4299500132882
# Sample log-like: 339.5042906704941
# Sample log-like: 339.5683876725859
# Sample log-like: 339.4771658247421
# Sample log-like: 339.4553922383325
# Sample log-like: 339.36789410337053
# Sample log-like: 339.51000232597113
# c:\users\apand\appdata\local\programs\python\python36\lib\site-packages\emcee\ensemble.py:335: RuntimeWarning: invalid value encountered in subtract
#   lnpdiff = (self.dim - 1.) * np.log(zz) + newlnprob - lnprob0
# c:\users\apand\appdata\local\programs\python\python36\lib\site-packages\emcee\ensemble.py:336: RuntimeWarning: invalid value encountered in greater
#   accept = (lnpdiff > np.log(self._random.rand(len(lnpdiff))))
# 0.0 percent complete
# 0.1 percent complete
# 0.2 percent complete
# 0.3 percent complete
# 0.4 percent complete
# 0.5 percent complete
# 0.6 percent complete
# 0.7 percent complete
# 0.8 percent complete
# 0.9 percent complete
# 1.0 percent complete
# 1.1 percent complete
# 1.2 percent complete
# 1.3 percent complete
# 1.4 percent complete
# 1.5 percent complete
# 1.6 percent complete
# 1.7 percent complete
# 1.8 percent complete
# 1.9 percent complete
# 2.0 percent complete
# 2.1 percent complete
# 2.2 percent complete
# 2.3 percent complete
# 2.4 percent complete
# 2.5 percent complete
# 2.6 percent complete
# 2.7 percent complete
# 2.8 percent complete
# 2.9 percent complete
# 3.0 percent complete
# c:\users\apand\appdata\local\programs\python\python36\lib\site-packages\scipy\stats\_continuous_distns.py:77: RuntimeWarning: overflow encountered in square
#   return np.exp(-x**2/2.0) / _norm_pdf_C
# 3.1 percent complete
# 3.2 percent complete
# 3.3 percent complete
# 3.4 percent complete
# 3.5 percent complete
# 3.6 percent complete
# 3.7 percent complete
# 3.8 percent complete
# 3.9 percent complete
# 4.0 percent complete
# 4.1 percent complete
# 4.2 percent complete
# 4.3 percent complete
# 4.4 percent complete
# 4.5 percent complete
# 4.6 percent complete
# 4.7 percent complete
# 4.8 percent complete
# 4.9 percent complete
# 5.0 percent complete
# 5.1 percent complete
# 5.2 percent complete
# 5.3 percent complete
# 5.4 percent complete
# 5.5 percent complete
# 5.6 percent complete
# 5.7 percent complete
# 5.8 percent complete
# c:\users\apand\appdata\local\programs\python\python36\lib\site-packages\bioscrape\pid_interfaces.py:151: RuntimeWarning: overflow encountered in exp
#   params_exp = np.exp(log_params)
# 5.9 percent complete
# 6.0 percent complete
# 6.1 percent complete
# 6.2 percent complete
# 6.3 percent complete
# 6.4 percent complete
# 6.5 percent complete
# 6.6 percent complete
# 6.7 percent complete
# 6.8 percent complete
# 6.9 percent complete
# 7.0 percent complete
# 7.1 percent complete
# 7.2 percent complete
# 7.3 percent complete
# 7.4 percent complete
# 7.5 percent complete
# 7.6 percent complete
# 7.7 percent complete
# 7.8 percent complete
# 7.9 percent complete
# 8.0 percent complete
# 8.1 percent complete
# 8.2 percent complete
# 8.3 percent complete
# 8.4 percent complete
# 8.5 percent complete
# 8.6 percent complete
# 8.7 percent complete
# 8.8 percent complete
# 8.9 percent complete
# 9.0 percent complete
# 9.1 percent complete
# 9.2 percent complete
# 9.3 percent complete
# 9.4 percent complete
# 9.5 percent complete
# 9.6 percent complete
# 9.7 percent complete
# 9.8 percent complete
# 9.9 percent complete
# 10.0 percent complete
# 10.1 percent complete
# 10.2 percent complete
# 10.3 percent complete
# 10.4 percent complete
# 10.5 percent complete
# 10.6 percent complete
# 10.7 percent complete
# 10.8 percent complete
# 10.9 percent complete
# 11.0 percent complete
# 11.1 percent complete
# 11.2 percent complete
# 11.3 percent complete
# 11.4 percent complete
# 11.5 percent complete
# 11.6 percent complete
# 11.7 percent complete
# 11.8 percent complete
# 11.9 percent complete
# 12.0 percent complete
# 12.1 percent complete
# 12.2 percent complete
# 12.3 percent complete
# 12.4 percent complete
# 12.5 percent complete
# 12.6 percent complete
# 12.7 percent complete
# 12.8 percent complete
# 12.9 percent complete
# 13.0 percent complete
# 13.1 percent complete
# 13.2 percent complete
# 13.3 percent complete
# 13.4 percent complete
# 13.5 percent complete
# 13.6 percent complete
# 13.7 percent complete
# 13.8 percent complete
# 13.9 percent complete
# 14.0 percent complete
# 14.1 percent complete
# 14.2 percent complete
# 14.3 percent complete
# 14.4 percent complete
# 14.5 percent complete
# 14.6 percent complete
# 14.7 percent complete
# 14.8 percent complete
# 14.9 percent complete
# 15.0 percent complete
# 15.1 percent complete
# 15.2 percent complete
# 15.3 percent complete
# 15.4 percent complete
# 15.5 percent complete
# 15.6 percent complete
# 15.7 percent complete
# 15.8 percent complete
# 15.9 percent complete
# 16.0 percent complete
# 16.1 percent complete
# 16.2 percent complete
# 16.3 percent complete
# 16.4 percent complete
# 16.5 percent complete
# 16.6 percent complete
# 16.7 percent complete
# 16.8 percent complete
# 16.9 percent complete
# 17.0 percent complete
# 17.1 percent complete
# 17.2 percent complete
# 17.3 percent complete
# 17.4 percent complete
# 17.5 percent complete
# 17.6 percent complete
# 17.7 percent complete
# 17.8 percent complete
# 17.9 percent complete
# 18.0 percent complete
# 18.1 percent complete
# 18.2 percent complete
# 18.3 percent complete
# 18.4 percent complete
# 18.5 percent complete
# 18.6 percent complete
# 18.7 percent complete
# 18.8 percent complete
# 18.9 percent complete
# 19.0 percent complete
# 19.1 percent complete
# 19.2 percent complete
# 19.3 percent complete
# 19.4 percent complete
# 19.5 percent complete
# 19.6 percent complete
# 19.7 percent complete
# 19.8 percent complete
# 19.9 percent complete
# 20.0 percent complete
# 20.1 percent complete
# 20.2 percent complete
# 20.3 percent complete
# 20.4 percent complete
# 20.5 percent complete
# 20.6 percent complete
# 20.7 percent complete
# 20.8 percent complete
# 20.9 percent complete
# 21.0 percent complete
# 21.1 percent complete
# 21.2 percent complete
# 21.3 percent complete
# 21.4 percent complete
# 21.5 percent complete
# 21.6 percent complete
# 21.7 percent complete
# 21.8 percent complete
# 21.9 percent complete
# 22.0 percent complete
# 22.1 percent complete
# 22.2 percent complete
# 22.3 percent complete
# 22.4 percent complete
# 22.5 percent complete
# 22.6 percent complete
# 22.7 percent complete
# 22.8 percent complete
# 22.9 percent complete
# 23.0 percent complete
# 23.1 percent complete
# 23.2 percent complete
# 23.3 percent complete
# 23.4 percent complete
# 23.5 percent complete
# 23.6 percent complete
# 23.7 percent complete
# 23.8 percent complete
# 23.9 percent complete
# 24.0 percent complete
# 24.1 percent complete
# 24.2 percent complete
# 24.3 percent complete
# 24.4 percent complete
# 24.5 percent complete
# 24.6 percent complete
# 24.7 percent complete
# 24.8 percent complete
# 24.9 percent complete
# 25.0 percent complete
# 25.1 percent complete
# 25.2 percent complete
# 25.3 percent complete
# 25.4 percent complete
# 25.5 percent complete
# 25.6 percent complete
# 25.7 percent complete
# 25.8 percent complete
# 25.9 percent complete
# 26.0 percent complete
# 26.1 percent complete
# 26.2 percent complete
# 26.3 percent complete
# 26.4 percent complete
# 26.5 percent complete
# 26.6 percent complete
# 26.7 percent complete
# 26.8 percent complete
# 26.9 percent complete
# 27.0 percent complete
# 27.1 percent complete
# 27.2 percent complete
# 27.3 percent complete
# 27.4 percent complete
# 27.5 percent complete
# 27.6 percent complete
# 27.7 percent complete
# 27.8 percent complete
# 27.9 percent complete
# 28.0 percent complete
# 28.1 percent complete
# 28.2 percent complete
# 28.3 percent complete
# 28.4 percent complete
# 28.5 percent complete
# 28.6 percent complete
# 28.7 percent complete
# 28.8 percent complete
# 28.9 percent complete
# 29.0 percent complete
# 29.1 percent complete
# 29.2 percent complete
# 29.3 percent complete
# 29.4 percent complete
# 29.5 percent complete
# 29.6 percent complete
# 29.7 percent complete
# 29.8 percent complete
# 29.9 percent complete
# 30.0 percent complete
# 30.1 percent complete
# 30.2 percent complete
# 30.3 percent complete
# 30.4 percent complete
# 30.5 percent complete
# 30.6 percent complete
# 30.7 percent complete
# 30.8 percent complete
# 30.9 percent complete
# 31.0 percent complete
# 31.1 percent complete
# 31.2 percent complete
# 31.3 percent complete
# 31.4 percent complete
# 31.5 percent complete
# 31.6 percent complete
# 31.7 percent complete
# 31.8 percent complete
# 31.9 percent complete
# 32.0 percent complete
# 32.1 percent complete
# 32.2 percent complete
# 32.3 percent complete
# 32.4 percent complete
# 32.5 percent complete
# 32.6 percent complete
# 32.7 percent complete
# 32.8 percent complete
# 32.9 percent complete
# 33.0 percent complete
# 33.1 percent complete
# 33.2 percent complete
# 33.3 percent complete
# 33.4 percent complete
# 33.5 percent complete
# 33.6 percent complete
# 33.7 percent complete
# 33.8 percent complete
# 33.9 percent complete
# 34.0 percent complete
# 34.1 percent complete
# 34.2 percent complete
# 34.3 percent complete
# 34.4 percent complete
# 34.5 percent complete
# 34.6 percent complete
# 34.7 percent complete
# 34.8 percent complete
# 34.9 percent complete
# 35.0 percent complete
# 35.1 percent complete
# 35.2 percent complete
# 35.3 percent complete
# 35.4 percent complete
# 35.5 percent complete
# 35.6 percent complete
# 35.7 percent complete
# 35.8 percent complete
# 35.9 percent complete
# 36.0 percent complete
# 36.1 percent complete
# 36.2 percent complete
# 36.3 percent complete
# 36.4 percent complete
# 36.5 percent complete
# 36.6 percent complete
# 36.7 percent complete
# 36.8 percent complete
# 36.9 percent complete
# 37.0 percent complete
# 37.1 percent complete
# 37.2 percent complete
# 37.3 percent complete
# 37.4 percent complete
# 37.5 percent complete
# 37.6 percent complete
# 37.7 percent complete
# 37.8 percent complete
# 37.9 percent complete
# 38.0 percent complete
# 38.1 percent complete
# 38.2 percent complete
# 38.3 percent complete
# 38.4 percent complete
# 38.5 percent complete
# 38.6 percent complete
# 38.7 percent complete
# 38.8 percent complete
# 38.9 percent complete
# 39.0 percent complete
# 39.1 percent complete
# 39.2 percent complete
# 39.3 percent complete
# 39.4 percent complete
# 39.5 percent complete
# 39.6 percent complete
# 39.7 percent complete
# 39.8 percent complete
# 39.9 percent complete
# 40.0 percent complete
# 40.1 percent complete
# 40.2 percent complete
# 40.3 percent complete
# 40.4 percent complete
# 40.5 percent complete
# 40.6 percent complete
# 40.7 percent complete
# 40.8 percent complete
# 40.9 percent complete
# 41.0 percent complete
# 41.1 percent complete
# 41.2 percent complete
# 41.3 percent complete
# 41.4 percent complete
# 41.5 percent complete
# 41.6 percent complete
# 41.7 percent complete
# 41.8 percent complete
# 41.9 percent complete
# 42.0 percent complete
# 42.1 percent complete
# 42.2 percent complete
# 42.3 percent complete
# 42.4 percent complete
# 42.5 percent complete
# 42.6 percent complete
# 42.7 percent complete
# 42.8 percent complete
# 42.9 percent complete
# 43.0 percent complete
# 43.1 percent complete
# 43.2 percent complete
# 43.3 percent complete
# 43.4 percent complete
# 43.5 percent complete
# 43.6 percent complete
# 43.7 percent complete
# 43.8 percent complete
# 43.9 percent complete
# 44.0 percent complete
# 44.1 percent complete
# 44.2 percent complete
# 44.3 percent complete
# 44.4 percent complete
# 44.5 percent complete
# 44.6 percent complete
# 44.7 percent complete
# 44.8 percent complete
# 44.9 percent complete
# 45.0 percent complete
# 45.1 percent complete
# 45.2 percent complete
# 45.3 percent complete
# 45.4 percent complete
# 45.5 percent complete
# 45.6 percent complete
# 45.7 percent complete
# 45.8 percent complete
# 45.9 percent complete
# 46.0 percent complete
# 46.1 percent complete
# 46.2 percent complete
# 46.3 percent complete
# 46.4 percent complete
# 46.5 percent complete
# 46.6 percent complete
# 46.7 percent complete
# 46.8 percent complete
# 46.9 percent complete
# 47.0 percent complete
# 47.1 percent complete
# 47.2 percent complete
# 47.3 percent complete
# 47.4 percent complete
# 47.5 percent complete
# 47.6 percent complete
# 47.7 percent complete
# 47.8 percent complete
# 47.9 percent complete
# 48.0 percent complete
# 48.1 percent complete
# 48.2 percent complete
# 48.3 percent complete
# 48.4 percent complete
# 48.5 percent complete
# 48.6 percent complete
# 48.7 percent complete
# 48.8 percent complete
# 48.9 percent complete
# 49.0 percent complete
# 49.1 percent complete
# 49.2 percent complete
# 49.3 percent complete
# 49.4 percent complete
# 49.5 percent complete
# 49.6 percent complete
# 49.7 percent complete
# 49.8 percent complete
# 49.9 percent complete
# 50.0 percent complete
# 50.1 percent complete
# 50.2 percent complete
# 50.3 percent complete
# 50.4 percent complete
# 50.5 percent complete
# 50.6 percent complete
# 50.7 percent complete
# 50.8 percent complete
# 50.9 percent complete
# 51.0 percent complete
# 51.1 percent complete
# 51.2 percent complete
# 51.3 percent complete
# 51.4 percent complete
# 51.5 percent complete
# 51.6 percent complete
# 51.7 percent complete
# 51.8 percent complete
# 51.9 percent complete
# 52.0 percent complete
# 52.1 percent complete
# 52.2 percent complete
# 52.3 percent complete
# 52.4 percent complete
# 52.5 percent complete
# 52.6 percent complete
# 52.7 percent complete
# 52.8 percent complete
# 52.9 percent complete
# 53.0 percent complete
# 53.1 percent complete
# 53.2 percent complete
# 53.3 percent complete
# 53.4 percent complete
# 53.5 percent complete
# 53.6 percent complete
# 53.7 percent complete
# 53.8 percent complete
# 53.9 percent complete
# 54.0 percent complete
# 54.1 percent complete
# 54.2 percent complete
# 54.3 percent complete
# 54.4 percent complete
# 54.5 percent complete
# 54.6 percent complete
# 54.7 percent complete
# 54.8 percent complete
# 54.9 percent complete
# 55.0 percent complete
# 55.1 percent complete
# 55.2 percent complete
# 55.3 percent complete
# 55.4 percent complete
# 55.5 percent complete
# 55.6 percent complete
# 55.7 percent complete
# 55.8 percent complete
# 55.9 percent complete
# 56.0 percent complete
# 56.1 percent complete
# 56.2 percent complete
# 56.3 percent complete
# 56.4 percent complete
# 56.5 percent complete
# 56.6 percent complete
# 56.7 percent complete
# 56.8 percent complete
# 56.9 percent complete
# 57.0 percent complete
# 57.1 percent complete
# 57.2 percent complete
# 57.3 percent complete
# 57.4 percent complete
# 57.5 percent complete
# 57.6 percent complete
# 57.7 percent complete
# 57.8 percent complete
# 57.9 percent complete
# 58.0 percent complete
# 58.1 percent complete
# 58.2 percent complete
# 58.3 percent complete
# 58.4 percent complete
# 58.5 percent complete
# 58.6 percent complete
# 58.7 percent complete
# 58.8 percent complete
# 58.9 percent complete
# 59.0 percent complete
# 59.1 percent complete
# 59.2 percent complete
# 59.3 percent complete
# 59.4 percent complete
# 59.5 percent complete
# 59.6 percent complete
# 59.7 percent complete
# 59.8 percent complete
# 59.9 percent complete
# 60.0 percent complete
# 60.1 percent complete
# 60.2 percent complete
# 60.3 percent complete
# 60.4 percent complete
# 60.5 percent complete
# 60.6 percent complete
# 60.7 percent complete
# 60.8 percent complete
# 60.9 percent complete
# 61.0 percent complete
# 61.1 percent complete
# 61.2 percent complete
# 61.3 percent complete
# 61.4 percent complete
# 61.5 percent complete
# 61.6 percent complete
# 61.7 percent complete
# 61.8 percent complete
# 61.9 percent complete
# 62.0 percent complete
# 62.1 percent complete
# 62.2 percent complete
# 62.3 percent complete
# 62.4 percent complete
# 62.5 percent complete
# 62.6 percent complete
# 62.7 percent complete
# 62.8 percent complete
# 62.9 percent complete
# 63.0 percent complete
# 63.1 percent complete
# 63.2 percent complete
# 63.3 percent complete
# 63.4 percent complete
# 63.5 percent complete
# 63.6 percent complete
# 63.7 percent complete
# 63.8 percent complete
# 63.9 percent complete
# 64.0 percent complete
# 64.1 percent complete
# 64.2 percent complete
# 64.3 percent complete
# 64.4 percent complete
# 64.5 percent complete
# 64.6 percent complete
# 64.7 percent complete
# 64.8 percent complete
# 64.9 percent complete
# 65.0 percent complete
# 65.1 percent complete
# 65.2 percent complete
# 65.3 percent complete
# 65.4 percent complete
# 65.5 percent complete
# 65.6 percent complete
# 65.7 percent complete
# 65.8 percent complete
# 65.9 percent complete
# 66.0 percent complete
# 66.1 percent complete
# 66.2 percent complete
# 66.3 percent complete
# 66.4 percent complete
# 66.5 percent complete
# 66.6 percent complete
# 66.7 percent complete
# 66.8 percent complete
# 66.9 percent complete
# 67.0 percent complete
# 67.1 percent complete
# 67.2 percent complete
# 67.3 percent complete
# 67.4 percent complete
# 67.5 percent complete
# 67.6 percent complete
# 67.7 percent complete
# 67.8 percent complete
# 67.9 percent complete
# 68.0 percent complete
# 68.1 percent complete
# 68.2 percent complete
# 68.3 percent complete
# 68.4 percent complete
# 68.5 percent complete
# 68.6 percent complete
# 68.7 percent complete
# 68.8 percent complete
# 68.9 percent complete
# 69.0 percent complete
# 69.1 percent complete
# 69.2 percent complete
# 69.3 percent complete
# 69.4 percent complete
# 69.5 percent complete
# 69.6 percent complete
# 69.7 percent complete
# 69.8 percent complete
# 69.9 percent complete
# 70.0 percent complete
# 70.1 percent complete
# 70.2 percent complete
# 70.3 percent complete
# 70.4 percent complete
# 70.5 percent complete
# 70.6 percent complete
# 70.7 percent complete
# 70.8 percent complete
# 70.9 percent complete
# 71.0 percent complete
# 71.1 percent complete
# 71.2 percent complete
# 71.3 percent complete
# 71.4 percent complete
# 71.5 percent complete
# 71.6 percent complete
# 71.7 percent complete
# 71.8 percent complete
# 71.9 percent complete
# 72.0 percent complete
# 72.1 percent complete
# 72.2 percent complete
# 72.3 percent complete
# 72.4 percent complete
# 72.5 percent complete
# 72.6 percent complete
# 72.7 percent complete
# 72.8 percent complete
# 72.9 percent complete
# 73.0 percent complete
# 73.1 percent complete
# 73.2 percent complete
# 73.3 percent complete
# 73.4 percent complete
# 73.5 percent complete
# 73.6 percent complete
# 73.7 percent complete
# 73.8 percent complete
# 73.9 percent complete
# 74.0 percent complete
# 74.1 percent complete
# 74.2 percent complete
# 74.3 percent complete
# 74.4 percent complete
# 74.5 percent complete
# 74.6 percent complete
# 74.7 percent complete
# 74.8 percent complete
# 74.9 percent complete
# 75.0 percent complete
# 75.1 percent complete
# 75.2 percent complete
# 75.3 percent complete
# 75.4 percent complete
# 75.5 percent complete
# 75.6 percent complete
# 75.7 percent complete
# 75.8 percent complete
# 75.9 percent complete
# 76.0 percent complete
# 76.1 percent complete
# 76.2 percent complete
# 76.3 percent complete
# 76.4 percent complete
# 76.5 percent complete
# 76.6 percent complete
# 76.7 percent complete
# 76.8 percent complete
# 76.9 percent complete
# 77.0 percent complete
# 77.1 percent complete
# 77.2 percent complete
# 77.3 percent complete
# 77.4 percent complete
# 77.5 percent complete
# 77.6 percent complete
# 77.7 percent complete
# 77.8 percent complete
# 77.9 percent complete
# 78.0 percent complete
# 78.1 percent complete
# 78.2 percent complete
# 78.3 percent complete
# 78.4 percent complete
# 78.5 percent complete
# 78.6 percent complete
# 78.7 percent complete
# 78.8 percent complete
# 78.9 percent complete
# 79.0 percent complete
# 79.1 percent complete
# 79.2 percent complete
# 79.3 percent complete
# 79.4 percent complete
# 79.5 percent complete
# 79.6 percent complete
# 79.7 percent complete
# 79.8 percent complete
# 79.9 percent complete
# 80.0 percent complete
# 80.1 percent complete
# 80.2 percent complete
# 80.3 percent complete
# 80.4 percent complete
# 80.5 percent complete
# 80.6 percent complete
# 80.7 percent complete
# 80.8 percent complete
# 80.9 percent complete
# 81.0 percent complete
# 81.1 percent complete
# 81.2 percent complete
# 81.3 percent complete
# 81.4 percent complete
# 81.5 percent complete
# 81.6 percent complete
# 81.7 percent complete
# 81.8 percent complete
# 81.9 percent complete
# 82.0 percent complete
# 82.1 percent complete
# 82.2 percent complete
# 82.3 percent complete
# 82.4 percent complete
# 82.5 percent complete
# 82.6 percent complete
# 82.7 percent complete
# 82.8 percent complete
# 82.9 percent complete
# 83.0 percent complete
# 83.1 percent complete
# 83.2 percent complete
# 83.3 percent complete
# 83.4 percent complete
# 83.5 percent complete
# 83.6 percent complete
# 83.7 percent complete
# 83.8 percent complete
# 83.9 percent complete
# 84.0 percent complete
# 84.1 percent complete
# 84.2 percent complete
# 84.3 percent complete
# 84.4 percent complete
# 84.5 percent complete
# 84.6 percent complete
# 84.7 percent complete
# 84.8 percent complete
# 84.9 percent complete
# 85.0 percent complete
# 85.1 percent complete
# 85.2 percent complete
# 85.3 percent complete
# 85.4 percent complete
# 85.5 percent complete
# 85.6 percent complete
# 85.7 percent complete
# 85.8 percent complete
# 85.9 percent complete
# 86.0 percent complete
# 86.1 percent complete
# 86.2 percent complete
# 86.3 percent complete
# 86.4 percent complete
# 86.5 percent complete
# 86.6 percent complete
# 86.7 percent complete
# 86.8 percent complete
# 86.9 percent complete
# 87.0 percent complete
# 87.1 percent complete
# 87.2 percent complete
# 87.3 percent complete
# 87.4 percent complete
# 87.5 percent complete
# 87.6 percent complete
# 87.7 percent complete
# 87.8 percent complete
# 87.9 percent complete
# 88.0 percent complete
# 88.1 percent complete
# 88.2 percent complete
# 88.3 percent complete
# 88.4 percent complete
# 88.5 percent complete
# 88.6 percent complete
# 88.7 percent complete
# 88.8 percent complete
# 88.9 percent complete
# 89.0 percent complete
# 89.1 percent complete
# 89.2 percent complete
# 89.3 percent complete
# 89.4 percent complete
# 89.5 percent complete
# 89.6 percent complete
# 89.7 percent complete
# 89.8 percent complete
# 89.9 percent complete
# 90.0 percent complete
# 90.1 percent complete
# 90.2 percent complete
# 90.3 percent complete
# 90.4 percent complete
# 90.5 percent complete
# 90.6 percent complete
# 90.7 percent complete
# 90.8 percent complete
# 90.9 percent complete
# 91.0 percent complete
# 91.1 percent complete
# 91.2 percent complete
# 91.3 percent complete
# 91.4 percent complete
# 91.5 percent complete
# 91.6 percent complete
# 91.7 percent complete
# 91.8 percent complete
# 91.9 percent complete
# 92.0 percent complete
# 92.1 percent complete
# 92.2 percent complete
# 92.3 percent complete
# 92.4 percent complete
# 92.5 percent complete
# 92.6 percent complete
# 92.7 percent complete
# 92.8 percent complete
# 92.9 percent complete
# 93.0 percent complete
# 93.1 percent complete
# 93.2 percent complete
# 93.3 percent complete
# 93.4 percent complete
# 93.5 percent complete
# 93.6 percent complete
# 93.7 percent complete
# 93.8 percent complete
# 93.9 percent complete
# 94.0 percent complete
# 94.1 percent complete
# 94.2 percent complete
# 94.3 percent complete
# 94.4 percent complete
# 94.5 percent complete
# 94.6 percent complete
# 94.7 percent complete
# 94.8 percent complete
# 94.9 percent complete
# 95.0 percent complete
# 95.1 percent complete
# 95.2 percent complete
# 95.3 percent complete
# 95.4 percent complete
# 95.5 percent complete
# 95.6 percent complete
# 95.7 percent complete
# 95.8 percent complete
# 95.9 percent complete
# 96.0 percent complete
# 96.1 percent complete
# 96.2 percent complete
# 96.3 percent complete
# 96.4 percent complete
# 96.5 percent complete
# 96.6 percent complete
# 96.7 percent complete
# 96.8 percent complete
# 96.9 percent complete
# 97.0 percent complete
# 97.1 percent complete
# 97.2 percent complete
# 97.3 percent complete
# 97.4 percent complete
# 97.5 percent complete
# 97.6 percent complete
# 97.7 percent complete
# 97.8 percent complete
# 97.9 percent complete
# 98.0 percent complete
# 98.1 percent complete
# 98.2 percent complete
# 98.3 percent complete
# 98.4 percent complete
# 98.5 percent complete
# 98.6 percent complete
# 98.7 percent complete
# 98.8 percent complete
# 98.9 percent complete
# 99.0 percent complete
# 99.1 percent complete
# 99.2 percent complete
# 99.3 percent complete
# 99.4 percent complete
# 99.5 percent complete
# 99.6 percent complete
# 99.7 percent complete
# 99.8 percent complete
# 99.9 percent complete
# Successfully completed MCMC parameter identification procedure. Parameter distribution data written to mcmc_results.csv file

# %% [markdown]
# ### Plot the results

# %%
timepoints = pid.timepoints
M_original = Model('toy_model.xml')
sim_x = py_simulate_model(timepoints, Model = M_original, stochastic = False)
sim_x_inf = py_simulate_model(timepoints, Model = fitted_model, stochastic = False)
plt.plot(timepoints, sim_x['X'], 'r--', label = 'Original model')
plt.plot(timepoints, data.get('X'), label = 'Experimental data')
plt.plot(timepoints, sim_x_inf['X'], 'k', label = 'Identified model')

plt.legend()

# %% [markdown]
# ### All methods above have other advanced options that you can use. Refer to Parameter Identification Tools notebook for more details. There are many other tools available such as for multiple initial conditions and timepoints for each trajectory, options for the estimator etc.
