# %%
import numpy as np
import pandas as pd

# Plotting code:
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

from matplotlib import rcParams
rcParams["savefig.dpi"] = 100
rcParams["figure.dpi"] = 100
rcParams["font.size"] = 20
import matplotlib.pyplot as plt

# %%
from bioscrape.simulator import py_simulate_model
from bioscrape.types import Model
#Create a list of species names (strings)
species = ["G", "T", "X", "I"]

#create a list of parameters in the form (param_name[string], param_val[number])
delay_tx = 10
delay_tl = 5
params = [("ktx", 15), ("ktl", 100.0), ("KI", 10), ("n", 2.0), ("KR", 20), 
          ("delta", .1), ("delay_tx", 10),("delay_tl", 5)]
#create reaction tuples with delays require additional elements. They are of the form:
#(Inputs[string list], Outputs[string list], propensity_type[string], propensity_dict {propensity_param:model_param},
# delay_type[string], DelayInputs [string list], DelayOutputs [string list], delay_param_dictionary {delay_param:model_param}).

rxn1d = (["G"], ["G"], "proportionalhillpositive", {"d":"G", "s1":"I", "k":"ktx", "K":"KI", "n":"n"},
       "gaussian", [], ["T"], {"mean":delay_tx, "std":5.0})
rxn2d = (["T"], ["T"], "hillpositive", {"s1":"T", "k":"ktl", "K":"KR", "n":1},
        "gamma", [], ["X"], {"k":delay_tl, "theta":3.0})
rxn3 = (["T"], [], "massaction", {"k":"delta"})
rxn4 = (["X"], [], "massaction", {"k":"delta"})
#Reactions 3 and 4 remain unchanged
rxns_delay = [rxn1d, rxn2d, rxn3, rxn4]
x0 = {"G":1, "I":10}

#Instaniate the Model object, species, params, and x0 remain unchanged from the previous example
M_delay = Model(species = species, parameters = params, reactions = rxns_delay, initial_condition_dict = x0)

#Simulate the Model with delay
timepoints = np.arange(0, 80, .1)
results_delay = py_simulate_model(timepoints, Model = M_delay, stochastic = True, delay = True)

#Plot the results
plt.figure(figsize = (12, 4))
plt.subplot(121)
plt.title("Transcript T")
plt.plot(timepoints, results_delay["T"])
plt.xlabel("Time")

plt.subplot(122)
plt.title("Protein X")
plt.plot(timepoints, results_delay["X"])
plt.xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %%
delay_data = pd.DataFrame()
delay_data['X'] = results_delay['X'] + np.random.normal(10, 10, size = np.shape(results_delay['X']))
delay_data['t'] = timepoints
plt.plot(delay_data['t'], delay_data['X'])

# %% [markdown]
# ## Least squares fit using LMFit and Bioscrape

# %%
from bioscrape.inference import py_inference
# Create prior for parameters
prior = {'DummyVar_GaussianDelay_mean_0':['uniform', 0, 1000],'DummyVar_GammaDelay_k_3':['uniform', 0, 100],
         'delta':['uniform', 0, 5], 'ktx':['uniform', 0, 100], 'ktl':['uniform', 20, 1000],
         'KR':['uniform', 0, 100], 'KI':['uniform', 0, 100]}
minimizer_results = py_inference(Model = M_delay, exp_data = delay_data, measurements = ['X'], time_column = ['t'],
                                 params_to_estimate = ['DummyVar_GaussianDelay_mean_0','DummyVar_GammaDelay_k_3', 
                                                       'delta', 'ktx', 'ktl', 'KR','KI'], 
                                 prior = prior, plot_show = True, 
                                 sim_type = 'stochastic',
                                 inference_type = 'lmfit', method = 'leastsq')
# Out:
# Successfully completed parameter identification procedure using LMFit. Parameter values and fitness reports written to lmfit_results.csv file. Check the minimizer_results object returned to further statistically evaluate the goodness of fit.

# %% [markdown]
# ## Note: The orange trajectories above are the model simulations and blue is the data. Check lmfit_results.csv for more information on parameter values and fitness reports.

# %%
minimizer_results[0]
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>9</td><td></td></tr><tr><td># data points</td><td>800</td><td></td></tr><tr><td># variables</td><td>7</td><td></td></tr><tr><td>chi-square</td><td> 49781569.3</td><td></td></tr><tr><td>reduced chi-square</td><td> 62776.2539</td><td></td></tr><tr><td>Akaike info crit.</td><td> 8844.83492</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 8877.62720</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> DummyVar_GaussianDelay_mean_0 </td><td>  10.0000086 </td><td>  8.4984e-07 </td><td> (0.00%) </td><td> 10.0 </td><td>  0.00000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> DummyVar_GammaDelay_k_3 </td><td>  5.00000005 </td><td>  1.4546e-07 </td><td> (0.00%) </td><td> 5.0 </td><td>  0.00000000 </td><td>  100.000000 </td><td> True </td></tr><tr><td> delta </td><td>  0.09999994 </td><td>  5.8842e-09 </td><td> (0.00%) </td><td> 0.1 </td><td>  0.00000000 </td><td>  5.00000000 </td><td> True </td></tr><tr><td> ktx </td><td>  15.0000004 </td><td>  1.6781e-07 </td><td> (0.00%) </td><td> 15.0 </td><td>  0.00000000 </td><td>  100.000000 </td><td> True </td></tr><tr><td> ktl </td><td>  99.9999976 </td><td>  2.0154e-06 </td><td> (0.00%) </td><td> 100.0 </td><td>  20.0000000 </td><td>  1000.00000 </td><td> True </td></tr><tr><td> KR </td><td>  20.0000010 </td><td>  1.5472e-07 </td><td> (0.00%) </td><td> 20.0 </td><td>  0.00000000 </td><td>  100.000000 </td><td> True </td></tr><tr><td> KI </td><td>  9.99999906 </td><td>  1.5102e-07 </td><td> (0.00%) </td><td> 10.0 </td><td>  0.00000000 </td><td>  100.000000 </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>DummyVar_GammaDelay_k_3</td><td>delta</td><td>0.7375</td></tr><tr><td>DummyVar_GaussianDelay_mean_0</td><td>ktx</td><td>-0.5111</td></tr><tr><td>delta</td><td>ktl</td><td>-0.4558</td></tr><tr><td>DummyVar_GammaDelay_k_3</td><td>KI</td><td>-0.4497</td></tr><tr><td>DummyVar_GaussianDelay_mean_0</td><td>KR</td><td>0.3596</td></tr><tr><td>DummyVar_GammaDelay_k_3</td><td>ktl</td><td>-0.3536</td></tr><tr><td>DummyVar_GaussianDelay_mean_0</td><td>delta</td><td>-0.3529</td></tr><tr><td>DummyVar_GaussianDelay_mean_0</td><td>DummyVar_GammaDelay_k_3</td><td>-0.3220</td></tr><tr><td>DummyVar_GammaDelay_k_3</td><td>ktx</td><td>-0.3157</td></tr><tr><td>ktl</td><td>KI</td><td>-0.3012</td></tr><tr><td>delta</td><td>KI</td><td>-0.2693</td></tr><tr><td>delta</td><td>ktx</td><td>-0.2570</td></tr><tr><td>delta</td><td>KR</td><td>-0.2087</td></tr><tr><td>ktx</td><td>KI</td><td>0.1987</td></tr><tr><td>ktx</td><td>ktl</td><td>0.1955</td></tr><tr><td>DummyVar_GammaDelay_k_3</td><td>KR</td><td>-0.1857</td></tr><tr><td>ktl</td><td>KR</td><td>0.1282</td></tr><tr><td>DummyVar_GaussianDelay_mean_0</td><td>ktl</td><td>-0.1135</td></tr><tr><td>DummyVar_GaussianDelay_mean_0</td><td>KI</td><td>-0.1057</td></tr></table>

# %%
import numpy as np
import pandas as pd

od_data = pd.read_csv('od_data.csv')
list_od_data = []
for ar in od_data.iloc[:, range(2,14)]:
    df = pd.DataFrame()
    df['t'] = od_data['t']
    df['C'] = od_data[ar]
    list_od_data.append(df)

# %%
# Plotting code:
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

from matplotlib import rcParams
rcParams["savefig.dpi"] = 100
rcParams["figure.dpi"] = 100
rcParams["font.size"] = 20
import matplotlib.pyplot as plt

# %%
plt.figure()
for i in range(len(od_data.iloc[:,range(2,14)].T)):
    
    plt.plot(np.array(od_data['t']), np.array(od_data.iloc[:,2+i]))
plt.xlabel('Time')
plt.ylabel('Cell count')
# Out:
# Text(0, 0.5, 'Cell count')

# %%
# Actual modeling code
from bioscrape.types import Model
from bioscrape.simulator import py_simulate_model
initial_condition = np.mean(od_data.iloc[0,range(2,14)])
M = Model(species = ['Cs'], parameters = {'k_c':10, 'C_max':0.6, 'd':1e-4},
          reactions = [([], [], 'general', {'rate':'k_c*(1- (Cs/C_max))*Cs - d*Cs'}, 
                       'gaussian', [],['Cs'], {'mean':80, 'std':10.0})],
          initial_condition_dict = {'Cs':initial_condition})
timepoints = np.array(od_data['t'])
sim_result = py_simulate_model(timepoints, Model = M, stochastic = True, delay = True)
# plt.plot(timepoints, sim_result['C'], 'b', lw = 4)
plt.plot(timepoints, sim_result['Cs'], 'r', lw = 4)
plt.xlabel('Time')
plt.ylabel('Cell count');

# %%
initial_condition
